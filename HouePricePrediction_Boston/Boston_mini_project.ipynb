# %% [markdown]
# ==============================================================================================

# %% [markdown]
# ## In this model i.e. Linear Regression model, <br>
# ***I made a Linear Regression model using the data provided for <br> Prediction of Median value of owner-occupied homes in $'1000' s <br> Using average number of rooms per dwelling***

# %% [markdown]
# ==============================================================================================

# %% [markdown]
# ___
# __I figured out using the heatmap that I need to use rm__
# ___

# %% [markdown]
# * Importing Modules

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd


from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
# Assigning Train and test to dataframes 

df_train = pd.read_csv("datasets/Boston_Train.csv")
df_test = pd.read_csv("datasets/Boston_Test.csv")

# %%
# Checking for the datatypes of variables in the df_train

df_train.dtypes
# Out:
# Unnamed: 0      int64
# crim          float64
# zn            float64
# indus         float64
# chas            int64
# nox           float64
# rm            float64
# age           float64
# dis           float64
# rad             int64
# tax             int64
# ptratio       float64
# black         float64
# lstat         float64
# medv          float64
# dtype: object

# %%
df_train
# Out:
#      Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0             0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1             1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2             2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3             3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4             4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
# ..          ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 346         346  0.06162   0.0   4.39     0  0.442  5.898  52.3  8.0136    3
# 347         347  0.01870  85.0   4.15     0  0.429  6.516  27.7  8.5353    4
# 348         348  0.01501  80.0   2.01     0  0.435  6.635  29.7  8.3440    4
# 349         349  0.02899  40.0   1.25     0  0.429  6.939  34.5  8.7921    1
# 350         350  0.06211  40.0   1.25     0  0.429  6.490  44.4  8.7921    1
#
#      tax  ptratio   black  lstat  medv
# 0    296     15.3  396.90   4.98  24.0
# 1    242     17.8  396.90   9.14  21.6
# 2    242     17.8  392.83   4.03  34.7
# 3    222     18.7  394.63   2.94  33.4
# 4    222     18.7  396.90   5.33  36.2
# ..   ...      ...     ...    ...   ...
# 346  352     18.8  364.61  12.67  17.2
# 347  351     17.9  392.43   6.36  23.1
# 348  280     17.0  390.94   5.99  24.5
# 349  335     19.7  389.85   5.89  26.6
# 350  335     19.7  396.90   5.98  22.9
#
# [351 rows x 15 columns]

# %%
df_train.drop("Unnamed: 0",inplace = True,axis =1)

# %%
# Creating heat map to check the correlation of variables

sns.heatmap(df_train.corr()) 
df_train.corr()
# Out:
#              crim        zn     indus      chas       nox        rm       age  \
# crim     1.000000 -0.298187  0.557235  0.129417  0.773321 -0.232369  0.487005
# zn      -0.298187  1.000000 -0.461280 -0.060150 -0.453540  0.327331 -0.516954
# indus    0.557235 -0.461280  1.000000  0.127674  0.669111 -0.384208  0.525184
# chas     0.129417 -0.060150  0.127674  1.000000  0.131093  0.037826  0.129274
# nox      0.773321 -0.453540  0.669111  0.131093  1.000000 -0.262861  0.667044
# rm      -0.232369  0.327331 -0.384208  0.037826 -0.262861  1.000000 -0.179751
# age      0.487005 -0.516954  0.525184  0.129274  0.667044 -0.179751  1.000000
# dis     -0.490656  0.592013 -0.594800 -0.153217 -0.719072  0.095919 -0.681234
# rad      0.140519 -0.187620  0.018118  0.087686  0.138287  0.094140  0.126482
# tax      0.406203 -0.109459  0.437328 -0.029835  0.394700 -0.204730  0.266733
# ptratio -0.222599 -0.323917  0.101026 -0.133981 -0.188388 -0.328928  0.049163
# black   -0.522173  0.141986 -0.311502 -0.054426 -0.427552  0.166340 -0.229513
# lstat    0.406877 -0.384008  0.512586  0.062915  0.488516 -0.680006  0.552882
# medv    -0.194024  0.334885 -0.365981  0.085798 -0.247384  0.894837 -0.256284
#
#               dis       rad       tax   ptratio     black     lstat      medv
# crim    -0.490656  0.140519  0.406203 -0.222599 -0.522173  0.406877 -0.194024
# zn       0.592013 -0.187620 -0.109459 -0.323917  0.141986 -0.384008  0.334885
# indus   -0.594800  0.018118  0.437328  0.101026 -0.311502  0.512586 -0.365981
# chas    -0.153217  0.087686 -0.029835 -0.133981 -0.054426  0.062915  0.085798
# nox     -0.719072  0.138287  0.394700 -0.188388 -0.427552  0.488516 -0.247384
# rm       0.095919  0.094140 -0.204730 -0.328928  0.166340 -0.680006  0.894837
# age     -0.681234  0.126482  0.266733  0.049163 -0.229513  0.552882 -0.256284
# dis      1.000000 -0.104500 -0.229837  0.023590  0.235331 -0.343134  0.047454
# rad     -0.104500  1.000000  0.229822 -0.023634 -0.060212 -0.026626  0.066628
# tax     -0.229837  0.229822  1.000000 -0.011439 -0.270342  0.240023 -0.286039
# ptratio  0.023590 -0.023634 -0.011439  1.000000  0.109199  0.214381 -0.441516
# black    0.235331 -0.060212 -0.270342  0.109199  1.000000 -0.228561  0.202029
# lstat   -0.343134 -0.026626  0.240023  0.214381 -0.228561  1.000000 -0.673181
# medv     0.047454  0.066628 -0.286039 -0.441516  0.202029 -0.673181  1.000000

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 351 entries, 0 to 350
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     351 non-null    float64
#  1   zn       351 non-null    float64
#  2   indus    351 non-null    float64
#  3   chas     351 non-null    int64
#  4   nox      351 non-null    float64
#  5   rm       351 non-null    float64
#  6   age      351 non-null    float64
#  7   dis      351 non-null    float64
#  8   rad      351 non-null    int64
#  9   tax      351 non-null    int64
#  10  ptratio  351 non-null    float64
#  11  black    351 non-null    float64
#  12  lstat    351 non-null    float64
#  13  medv     351 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 38.5 KB

# %%
df_train.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#     black  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
X =np.array( df_train["rm"] )
y = np.array(df_train["medv"])
X_train = X.reshape(-1,1)

# %%
# Importing Linear regression modules for algorithms to be integrated with model 

from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
ml = lr.fit(X_train,y) # Model declaration

# %%
ml.intercept_
# Out:
# -46.62397204400662

# %%
ml.coef_
# Out:
# array([11.1942171])

# %%
df_test
# Out:
#      Unnamed: 0     crim    zn  indus  chas    nox     rm   age      dis  rad  \
# 0           351  0.07950  60.0   1.69     0  0.411  6.579  35.9  10.7103    4
# 1           352  0.07244  60.0   1.69     0  0.411  5.884  18.5  10.7103    4
# 2           353  0.01709  90.0   2.02     0  0.410  6.728  36.1  12.1265    5
# 3           354  0.04301  80.0   1.91     0  0.413  5.663  21.9  10.5857    4
# 4           355  0.10659  80.0   1.91     0  0.413  5.936  19.5  10.5857    4
# ..          ...      ...   ...    ...   ...    ...    ...   ...      ...  ...
# 150         501  0.06263   0.0  11.93     0  0.573  6.593  69.1   2.4786    1
# 151         502  0.04527   0.0  11.93     0  0.573  6.120  76.7   2.2875    1
# 152         503  0.06076   0.0  11.93     0  0.573  6.976  91.0   2.1675    1
# 153         504  0.10959   0.0  11.93     0  0.573  6.794  89.3   2.3889    1
# 154         505  0.04741   0.0  11.93     0  0.573  6.030  80.8   2.5050    1
#
#      tax  ptratio   black  lstat  medv
# 0    411     18.3  370.78   5.49  24.1
# 1    411     18.3  392.33   7.79  18.6
# 2    187     17.0  384.46   4.50  30.1
# 3    334     22.0  382.80   8.05  18.2
# 4    334     22.0  376.04   5.57  20.6
# ..   ...      ...     ...    ...   ...
# 150  273     21.0  391.99   9.67  22.4
# 151  273     21.0  396.90   9.08  20.6
# 152  273     21.0  396.90   5.64  23.9
# 153  273     21.0  393.45   6.48  22.0
# 154  273     21.0  396.90   7.88  11.9
#
# [155 rows x 15 columns]

# %%
df_test.drop("Unnamed: 0",inplace = True,axis =1)

# %%
df_test.dropna()
df_test
# Out:
#         crim    zn  indus  chas    nox     rm   age      dis  rad  tax  \
# 0    0.07950  60.0   1.69     0  0.411  6.579  35.9  10.7103    4  411
# 1    0.07244  60.0   1.69     0  0.411  5.884  18.5  10.7103    4  411
# 2    0.01709  90.0   2.02     0  0.410  6.728  36.1  12.1265    5  187
# 3    0.04301  80.0   1.91     0  0.413  5.663  21.9  10.5857    4  334
# 4    0.10659  80.0   1.91     0  0.413  5.936  19.5  10.5857    4  334
# ..       ...   ...    ...   ...    ...    ...   ...      ...  ...  ...
# 150  0.06263   0.0  11.93     0  0.573  6.593  69.1   2.4786    1  273
# 151  0.04527   0.0  11.93     0  0.573  6.120  76.7   2.2875    1  273
# 152  0.06076   0.0  11.93     0  0.573  6.976  91.0   2.1675    1  273
# 153  0.10959   0.0  11.93     0  0.573  6.794  89.3   2.3889    1  273
# 154  0.04741   0.0  11.93     0  0.573  6.030  80.8   2.5050    1  273
#
#      ptratio   black  lstat  medv
# 0       18.3  370.78   5.49  24.1
# 1       18.3  392.33   7.79  18.6
# 2       17.0  384.46   4.50  30.1
# 3       22.0  382.80   8.05  18.2
# 4       22.0  376.04   5.57  20.6
# ..       ...     ...    ...   ...
# 150     21.0  391.99   9.67  22.4
# 151     21.0  396.90   9.08  20.6
# 152     21.0  396.90   5.64  23.9
# 153     21.0  393.45   6.48  22.0
# 154     21.0  396.90   7.88  11.9
#
# [155 rows x 14 columns]

# %%
df_test.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age      dis  rad  tax  ptratio  \
# 0  0.07950  60.0   1.69     0  0.411  6.579  35.9  10.7103    4  411     18.3
# 1  0.07244  60.0   1.69     0  0.411  5.884  18.5  10.7103    4  411     18.3
# 2  0.01709  90.0   2.02     0  0.410  6.728  36.1  12.1265    5  187     17.0
# 3  0.04301  80.0   1.91     0  0.413  5.663  21.9  10.5857    4  334     22.0
# 4  0.10659  80.0   1.91     0  0.413  5.936  19.5  10.5857    4  334     22.0
#
#     black  lstat  medv
# 0  370.78   5.49  24.1
# 1  392.33   7.79  18.6
# 2  384.46   4.50  30.1
# 3  382.80   8.05  18.2
# 4  376.04   5.57  20.6

# %%
X_test =np.array(df_test['rm'] )
y_test =  np.array(df_test["medv"])
X_test
# Out:
# array([6.579, 5.884, 6.728, 5.663, 5.936, 6.212, 6.395, 6.127, 6.112,
#        6.398, 6.251, 5.362, 5.803, 8.78 , 3.561, 4.963, 3.863, 4.97 ,
#        6.683, 7.016, 6.216, 5.875, 4.906, 4.138, 7.313, 6.649, 6.794,
#        6.38 , 6.223, 6.968, 6.545, 5.536, 5.52 , 4.368, 5.277, 4.652,
#        5.   , 4.88 , 5.39 , 5.713, 6.051, 5.036, 6.193, 5.887, 6.471,
#        6.405, 5.747, 5.453, 5.852, 5.987, 6.343, 6.404, 5.349, 5.531,
#        5.683, 4.138, 5.608, 5.617, 6.852, 5.757, 6.657, 4.628, 5.155,
#        4.519, 6.434, 6.782, 5.304, 5.957, 6.824, 6.411, 6.006, 5.648,
#        6.103, 5.565, 5.896, 5.837, 6.202, 6.193, 6.38 , 6.348, 6.833,
#        6.425, 6.436, 6.208, 6.629, 6.461, 6.152, 5.935, 5.627, 5.818,
#        6.406, 6.219, 6.485, 5.854, 6.459, 6.341, 6.251, 6.185, 6.417,
#        6.749, 6.655, 6.297, 7.393, 6.728, 6.525, 5.976, 5.936, 6.301,
#        6.081, 6.701, 6.376, 6.317, 6.513, 6.209, 5.759, 5.952, 6.003,
#        5.926, 5.713, 6.167, 6.229, 6.437, 6.98 , 5.427, 6.162, 6.484,
#        5.304, 6.185, 6.229, 6.242, 6.75 , 7.061, 5.762, 5.871, 6.312,
#        6.114, 5.905, 5.454, 5.414, 5.093, 5.983, 5.983, 5.707, 5.926,
#        5.67 , 5.39 , 5.794, 6.019, 5.569, 6.027, 6.593, 6.12 , 6.976,
#        6.794, 6.03 ])

# %%
X_test =(X_test).reshape(-1,1)
X_test
# Out:
# array([[6.579],
#        [5.884],
#        [6.728],
#        [5.663],
#        [5.936],
#        [6.212],
#        [6.395],
#        [6.127],
#        [6.112],
#        [6.398],
#        [6.251],
#        [5.362],
#        [5.803],
#        [8.78 ],
#        [3.561],
#        [4.963],
#        [3.863],
#        [4.97 ],
#        [6.683],
#        [7.016],
#        [6.216],
#        [5.875],
#        [4.906],
#        [4.138],
#        [7.313],
#        [6.649],
#        [6.794],
#        [6.38 ],
#        [6.223],
#        [6.968],
#        [6.545],
#        [5.536],
#        [5.52 ],
#        [4.368],
#        [5.277],
#        [4.652],
#        [5.   ],
#        [4.88 ],
#        [5.39 ],
#        [5.713],
#        [6.051],
#        [5.036],
#        [6.193],
#        [5.887],
#        [6.471],
#        [6.405],
#        [5.747],
#        [5.453],
#        [5.852],
#        [5.987],
#        [6.343],
#        [6.404],
#        [5.349],
#        [5.531],
#        [5.683],
#        [4.138],
#        [5.608],
#        [5.617],
#        [6.852],
#        [5.757],
#        [6.657],
#        [4.628],
#        [5.155],
#        [4.519],
#        [6.434],
#        [6.782],
#        [5.304],
#        [5.957],
#        [6.824],
#        [6.411],
#        [6.006],
#        [5.648],
#        [6.103],
#        [5.565],
#        [5.896],
#        [5.837],
#        [6.202],
#        [6.193],
#        [6.38 ],
#        [6.348],
#        [6.833],
#        [6.425],
#        [6.436],
#        [6.208],
#        [6.629],
#        [6.461],
#        [6.152],
#        [5.935],
#        [5.627],
#        [5.818],
#        [6.406],
#        [6.219],
#        [6.485],
#        [5.854],
#        [6.459],
#        [6.341],
#        [6.251],
#        [6.185],
#        [6.417],
#        [6.749],
#        [6.655],
#        [6.297],
#        [7.393],
#        [6.728],
#        [6.525],
#        [5.976],
#        [5.936],
#        [6.301],
#        [6.081],
#        [6.701],
#        [6.376],
#        [6.317],
#        [6.513],
#        [6.209],
#        [5.759],
#        [5.952],
#        [6.003],
#        [5.926],
#        [5.713],
#        [6.167],
#        [6.229],
#        [6.437],
#        [6.98 ],
#        [5.427],
#        [6.162],
#        [6.484],
#        [5.304],
#        [6.185],
#        [6.229],
#        [6.242],
#        [6.75 ],
#        [7.061],
#        [5.762],
#        [5.871],
#        [6.312],
#        [6.114],
#        [5.905],
#        [5.454],
#        [5.414],
#        [5.093],
#        [5.983],
#        [5.983],
#        [5.707],
#        [5.926],
#        [5.67 ],
#        [5.39 ],
#        [5.794],
#        [6.019],
#        [5.569],
#        [6.027],
#        [6.593],
#        [6.12 ],
#        [6.976],
#        [6.794],
#        [6.03 ]])

# %%
y_pred = ml.predict(X_test)

# %%
y_pred
# Out:
# array([27.02278229, 19.2428014 , 28.69072064, 16.76887942, 19.82490069,
#        22.91450461, 24.96304634, 21.96299616, 21.7950829 , 24.99662899,
#        23.35107908, 13.39942007, 18.33606982, 51.66125414, -6.76136493,
#         8.93292745, -3.38071137,  9.01128697, 28.18698087, 31.91465516,
#        22.95928148, 19.14205345,  8.29485707, -0.30230166, 35.23933764,
#        27.80637749, 29.42953897, 24.79513308, 23.037641  , 31.37733274,
#        26.64217891, 15.34721385, 15.16810637,  2.27236827, 12.44791162,
#         5.45152593,  9.34711348,  8.00380743, 13.71285815, 17.32859028,
#        21.11223566,  9.7501053 , 22.70181449, 19.27638405, 25.81380684,
#        25.07498851, 17.70919366, 14.41809383, 18.88458645, 20.39580576,
#        24.38094705, 25.0637943 , 13.25389525, 15.29124276, 16.99276376,
#        -0.30230166, 16.15319748, 16.25394543, 30.07880356, 17.82113583,
#        27.89593122,  5.18286472, 11.08221713,  3.96269505, 25.39962081,
#        29.29520836, 12.75015548, 20.05997925, 29.76536548, 25.14215381,
#        20.60849589, 16.60096616, 21.69433495, 15.67184614, 19.37713201,
#        18.7166732 , 22.80256244, 22.70181449, 24.79513308, 24.43691814,
#        29.86611343, 25.29887285, 25.42200924, 22.86972774, 27.58249314,
#        25.70186467, 22.24285158, 19.81370647, 16.3658876 , 18.50398307,
#        25.08618273, 22.99286413, 25.97052588, 18.90697489, 25.67947624,
#        24.35855862, 23.35107908, 22.61226075, 25.20931912, 28.9257992 ,
#        27.87354279, 23.86601306, 36.13487501, 28.69072064, 26.41829456,
#        20.27266937, 19.82490069, 23.91078993, 21.44806217, 28.38847678,
#        24.75035622, 24.08989741, 26.28396396, 22.88092196, 17.84352426,
#        20.00400816, 20.57491324, 19.71295852, 17.32859028, 22.41076484,
#        23.1048063 , 25.43320346, 31.51166335, 14.12704418, 22.35479376,
#        25.95933166, 12.75015548, 22.61226075, 23.1048063 , 23.25033112,
#        28.93699341, 32.41839493, 17.87710691, 19.09727658, 24.03392632,
#        21.81747133, 19.47787996, 14.42928805, 13.98151936, 10.38817567,
#        20.35102889, 20.35102889, 17.26142497, 19.71295852, 16.84723894,
#        13.71285815, 18.23532186, 20.75402071, 15.71662301, 20.84357445,
#        27.17950133, 21.88463664, 31.46688648, 29.42953897, 20.8771571 ])

# %%
plt.plot(X_test,y_pred,c ='r',label = 'Predicted')
plt.scatter(X,y, label = 'Actual')
plt.xlabel('RM')
plt.ylabel('MEDV')
plt.legend()
plt.show()

# %% [markdown]
#  * Checking for the errors

# %%
np.sqrt(mean_squared_error(y_test, y_pred))
# Out:
# 11.037022061401384

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 121.81585598386087

# %%
mean_absolute_error(y_test, y_pred)
# Out:
# 8.372597033187146

# %%
r2_score(y_test, y_pred)
# Out:
# -0.8293898494555747

# %% [markdown]
# ==============================================================================================

# %% [markdown]
# ## In this model i.e. Polynomial Regression model, <br>
# ***I made a Polynomial Regression model using the data provided for <br> Prediction of Median value of owner-occupied homes in $'1000' s <br> Using percent lower status of the population***

# %% [markdown]
# ==============================================================================================

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
sns.pairplot(df_train)

# %% [markdown]
#  - As it is evident from above pairplot that lstat and medv have a polynomial relation

# %%
X_train_pr =np.array( df_train['lstat']).reshape(-1,1)
y_train_pr =np.array(df_train['medv'])

X_test_pr =np.array(df_test['lstat']).reshape(-1,1)
y_test_pr =np.array(df_test['medv'])

# %%
plt.scatter(X_train_pr,y_train_pr)
plt.show()

# %%
ply = PolynomialFeatures(degree = 2)

# %%
ply
# Out:
# PolynomialFeatures()

# %%
ply.fit(X_train_pr)
# Out:
# PolynomialFeatures()

# %%
reg_pr = LinearRegression()

# %%
X_train_polyreg = ply.transform(np.array(X_train_pr).reshape(-1, 1))
X_test_polyreg = ply.transform(np.array(X_test_pr).reshape(-1, 1))

# %%
ml_pr = reg_pr.fit(X_train_polyreg,y_train_pr)

# %%
y_pred_pr = ml_pr.predict(X_test_polyreg)

# %%
plt.scatter(X_test_pr, y_pred_pr, color = "b",marker="X",label = "Predcted")
plt.scatter(X_test_pr, y_test_pr, color = 'r', label = "Actual")

plt.xlabel("medv")
plt.ylabel("lstat")
plt.legend()
plt.show()

# %%
r2_score(y_test_pr, y_pred)
# Out:
# -0.8293898494555747

# %%
mean_squared_error(y_test_pr, y_pred)
# Out:
# 121.81585598386087

# %%
mean_absolute_error(y_test_pr, y_pred)
# Out:
# 8.372597033187146

# %%
np.sqrt(mean_squared_error(y_test_pr, y_pred))
# Out:
# 11.037022061401384

# %% [markdown]
# ### This is under My contribution to [HacktoberFest](https://hacktoberfest.com)
#
# My Socials
#
#
# [Github](https://github.com/Aditya-lawate-codez?tab=repositories) <br/>
# [LinkedIn](https://www.linkedin.com/in/aditya-lawate/) <br/>
